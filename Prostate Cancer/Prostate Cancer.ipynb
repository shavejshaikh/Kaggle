# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("Prostate_Cancer.csv")
df.head()
# Out:
#    id diagnosis_result  radius  texture  perimeter  area  smoothness  \
# 0   1                M      23       12        151   954       0.143
# 1   2                B       9       13        133  1326       0.143
# 2   3                M      21       27        130  1203       0.125
# 3   4                M      14       16         78   386       0.070
# 4   5                M       9       19        135  1297       0.141
#
#    compactness  symmetry  fractal_dimension
# 0        0.278     0.242              0.079
# 1        0.079     0.181              0.057
# 2        0.160     0.207              0.060
# 3        0.284     0.260              0.097
# 4        0.133     0.181              0.059

# %%
df=df.drop('id',axis=1)

# %%
df.diagnosis_result =[1 if each == 'M' else 0 for each in df.diagnosis_result]

# %%
df
# Out:
#     diagnosis_result  radius  texture  perimeter  area  smoothness  \
# 0                  1      23       12        151   954       0.143
# 1                  0       9       13        133  1326       0.143
# 2                  1      21       27        130  1203       0.125
# 3                  1      14       16         78   386       0.070
# 4                  1       9       19        135  1297       0.141
# ..               ...     ...      ...        ...   ...         ...
# 95                 1      23       16        132  1264       0.091
# 96                 0      22       14         78   451       0.105
# 97                 0      19       27         62   295       0.102
# 98                 0      21       24         74   413       0.090
# 99                 1      16       27         94   643       0.098
#
#     compactness  symmetry  fractal_dimension
# 0         0.278     0.242              0.079
# 1         0.079     0.181              0.057
# ...

# %% [markdown]
# ## Find Null Values

# %%
sn.heatmap(df.isnull(),cmap='viridis',yticklabels=False,cbar=False)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
plt.plot(df['radius'],np.zeros_like(df['radius']),color='red')
plt.plot(df['texture'],np.zeros_like(df['texture']),color='green')

# %%
sn.FacetGrid(df,hue='diagnosis_result',height=7).map(plt.scatter,'radius','texture').add_legend()
plt.show()

# %%
sn.pairplot(df,hue='diagnosis_result')
